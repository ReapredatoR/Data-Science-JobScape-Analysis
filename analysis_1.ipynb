# %% [markdown]
# Analysis 1: Data Science Job Trends Over Time

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np 
from tabulate import tabulate

# %% [markdown]
# Loading cleaned data

# %%
cleaned_data = pd.read_csv('Data/Cleaned_Dataset.csv')
cleaned_data.head()
# Out:
#    work_year             job_title                    job_category  \
# 0       2023  Data DevOps Engineer                Data Engineering
# 1       2023        Data Architect  Data Architecture and Modeling
# 2       2023        Data Architect  Data Architecture and Modeling
# 3       2023        Data Scientist       Data Science and Research
# 4       2023        Data Scientist       Data Science and Research
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
#
#   employment_type work_setting company_location company_size
# ...

# %%
unique_categories = cleaned_data['job_category'].unique()
print("Available Job Categories:")
print(unique_categories)
# Out:
# Available Job Categories:
# ['Data Engineering' 'Data Architecture and Modeling'
#  'Data Science and Research' 'Machine Learning and AI' 'Data Analysis'
#  'Leadership and Management' 'BI and Visualization'
#  'Data Quality and Operations' 'Data Management and Strategy'
#  'Cloud and Database']

# %%
trend_details = pd.DataFrame()

job_categories = cleaned_data['job_category'].unique()

plt.figure(figsize=(12, 6))

for category in job_categories:
    category_data = cleaned_data[cleaned_data['job_category'] == category]
    category_trend = category_data.groupby('work_year')['job_category'].count()

    trend_details[category] = category_trend
    
    plt.plot(category_trend, marker='o', label=category)

plt.title('Job Trends Over Time by Job Category')
plt.xlabel('Year')
plt.ylabel('Number of Jobs')
plt.legend(title='Job Category', loc='upper right', bbox_to_anchor=(1.15, 1))
plt.show()

# %%
print("Trend Details:")
print(tabulate(trend_details, headers='keys', tablefmt='pretty'))
# Out:
# Trend Details:
# +-----------+------------------+--------------------------------+---------------------------+-------------------------+---------------+---------------------------+----------------------+-----------------------------+------------------------------+--------------------+
# | work_year | Data Engineering | Data Architecture and Modeling | Data Science and Research | Machine Learning and AI | Data Analysis | Leadership and Management | BI and Visualization | Data Quality and Operations | Data Management and Strategy | Cloud and Database |
# +-----------+------------------+--------------------------------+---------------------------+-------------------------+---------------+---------------------------+----------------------+-----------------------------+------------------------------+--------------------+
# ...

# %% [markdown]
#  Filter the Dataset for 'Data Science and Research' job categories

# %%
data_science_and_research_job_trend = cleaned_data[cleaned_data['job_category'] == 'Data Science and Research'].groupby('work_year')['job_category'].count()

# %%
data_science_and_research_job_trend.plot(kind='line', marker='o', title='Data Science Job Trends Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Jobs')
plt.show()

# %%
print("Data Science and Research Job Trends Over Time: ")
print(data_science_and_research_job_trend)
# Out:
# Data Science and Research Job Trends Over Time:
# work_year
# 2020      29
# 2021      71
# 2022     338
# 2023    1217
# Name: job_category, dtype: int64
